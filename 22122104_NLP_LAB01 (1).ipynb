# %% [markdown]
# __Name:__ Amrita Veshin <br>
# __Register Number:__ 22122104
#
# ----------------------------------------------------------------------------------------------------
# #<center>NLP Lab01: POS Tagging and Tokenizing Text
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# __AIM:__ Take any text of minimum 2000 words and extract the relevant tokens.<br>
# 1. Remove prefix, suffix, Exception, stop words, numbers, symbols, URLs
# 2. Make sure the tokens are clean.
# 3. Print the Text, POS, DEP, Lemmas of the tokens retrieved.

# %%
# Import spaCy and load the language library
import spacy
nlp = spacy.load('en_core_web_sm') #storing the english dictionary as an object named 'nlp'

# %%
text="""In the year 2023, the world faced many challenges, including the COVID-19 pandemic, which began in 2019. The pandemic led to a global economic downturn, with stock markets plummeting and unemployment rates soaring. It was a period of uncertainty, and people were searching for answers.
Amid the chaos, technology continued to advance at a rapid pace. Companies like Apple released the iPhone 15, featuring a stunning 8K display and a new AI-powered virtual assistant named SiriX. Tesla launched the Model Z, a self-driving electric car that revolutionized the automotive industry.
Financial markets experienced significant fluctuations. The Dow Jones Industrial Average dropped by 30% in March but recovered by the end of the year. Cryptocurrencies like Bitcoin and Ethereum also saw wild price swings, with Bitcoin reaching an all-time high of $100,000 before a sharp correction.
As the world adapted to remote work and online learning, cybersecurity became a critical concern. Cyberattacks on major organizations surged, with hackers demanding hefty ransoms in cryptocurrency. Governments worldwide implemented stricter regulations to combat cyber threats.
The scientific community achieved remarkable breakthroughs. In physics, researchers confirmed the existence of dark matter particles, providing new insights into the nature of the universe. The James Webb Space Telescope, launched in 2021, sent back breathtaking images of distant galaxies.
Artificial intelligence continued to shape various industries. Healthcare saw the emergence of AI-powered diagnosis tools that could detect diseases with incredible accuracy. Meanwhile, the entertainment industry utilized AI algorithms to create realistic CGI characters and immersive virtual reality experiences.
Education transformed with the rise of online learning platforms. Students could attend virtual classrooms, and AI-driven tutors provided personalized assistance. Massive Open Online Courses (MOOCs) became even more popular, offering access to quality education for millions worldwide.
In the world of sports, athletes pushed the limits of human performance. Usain Bolt's record-breaking 100-meter sprint time of 8.9 seconds stunned the world. In soccer, a robot named RoboStriker scored a perfect hat-trick in the FIFA World Cup finals.
Amidst these technological advancements, concerns about data privacy and ethics grew. Discussions around AI ethics and the responsible use of technology intensified, leading to the development of AI ethics guidelines and regulations.
The year 2023 marked a turning point in renewable energy. Solar and wind power became the dominant sources of electricity worldwide, leading to a significant reduction in carbon emissions. Electric airplanes also made their debut, offering a greener alternative for long-distance travel.
In the vast realm of digital technology, numbers and symbols intertwine to shape our modern world. From the binary code powering your computer to the complex algorithms guiding your online experiences, these numerical and symbolic entities are the building blocks of the digital age.
Let's start with the basics. The number system we commonly use is decimal, based on ten unique digits (0-9). But in the digital universe, the fundamental language is binary, relying on just two digits: 0 and 1. Every piece of data, whether it's a text message, a photo, or a video, is ultimately represented as a series of binary digits.

Take, for instance, the letter 'A.' In the ASCII (American Standard Code for Information Interchange) encoding, 'A' is represented as 01000001 in binary. Each character, symbol, or number you encounter on your screen has a corresponding binary code, allowing computers to process and display information.
As you navigate the internet, you encounter a plethora of symbols and numbers. URLs (Uniform Resource Locators) are a prime example. Consider the following URL: https://www.example.com:8080/path/to/page. It's a combination of symbols, numbers, and letters. 'https' stands for Hypertext Transfer Protocol Secure, 'www.example.com' is the domain name, ':8080' is the port number, and '/path/to/page' is the path to a specific web page. All these elements come together to help your browser find and display the requested web content.
Numbers are equally ubiquitous online. Your IP (Internet Protocol) address, a numerical label assigned to your device, is your digital fingerprint on the web. It consists of four sets of numbers, such as 192.168.1.1, which helps routers and servers route data to the correct destination. Additionally, the URLs you visit, the data you download, and the videos you stream all involve the transmission of numerical data across vast networks.
Symbols like '@' and '#' have found new significance in the digital age. The '@' symbol, once primarily used in email addresses, now plays a crucial role in social media handles, linking people in the global digital community. The '#' symbol, known as a hashtag, categorizes and organizes content on platforms like Twitter and Instagram, enabling users to discover relevant discussions and trends.
Behind the scenes, algorithms fuelled by numbers and symbols power the digital services you rely on daily. Search engines like Google use complex algorithms to deliver precise search results based on your queries. Social media platforms employ algorithms to curate your news feed, showing you content that aligns with your interests and behavior. Even online shopping platforms utilize recommendation algorithms to suggest products you might like, based on your browsing and purchasing history.
Numbers and symbols have also revolutionized the financial world. Cryptocurrencies like Bitcoin and Ethereum rely on cryptographic algorithms to secure transactions and create digital currencies that operate independently of traditional banks. The values of these cryptocurrencies are expressed as numbers, and transactions are validated through complex mathematical processes.
In the realm of gaming, numbers and symbols drive immersive experiences. Video game graphics are rendered using complex mathematical formulas, and scores and achievements are tracked with numerical values. In massively multiplayer online games, symbols like guild emblems and character avatars serve as visual representations of players' digital identities.
The influence of numbers and symbols extends beyond the digital realm. In science and mathematics, symbols like π (pi) and ∑ (sigma) are essential tools for representing mathematical concepts and equations. These symbols enable scientists and mathematicians to express complex ideas succinctly and elegantly.
In literature and art, symbols have deep cultural and historical significance. Authors use symbols to convey deeper meanings and themes in their works, while artists employ symbols to create visual metaphors that resonate with viewers. For example, the dove is a symbol of peace, while the red rose represents love and passion.

Religious and spiritual traditions also rely heavily on symbols and numbers. The cross, the crescent moon, and the lotus flower are just a few examples of symbols with profound religious significance. Numerology, the study of the mystical significance of numbers, is prevalent in various belief systems, influencing everything from sacred texts to rituals.
The Beauty of Nature and Human Connection
In our fast-paced, modern world, it's easy to lose touch with the beauty of nature and the profound impact it has on our lives. We often find ourselves caught up in the hustle and bustle of daily routines, glued to screens, and disconnected from the natural world that surrounds us. But it's essential to remember that nature offers us more than just scenic views; it provides a deep and meaningful connection that can heal our souls and bring us peace.
Imagine standing on the shore of a tranquil lake, the water reflecting the clear blue sky. As you take a deep breath, you can smell the crispness of the air, tinged with the scent of pine trees nearby. The sound of rustling leaves and chirping birds fills your ears, and you feel a gentle breeze brushing against your skin. In this moment, you are one with nature, and it's as if all your worries and stress have melted away.
Nature has an incredible ability to soothe our minds and bodies. Studies have shown that spending time in natural environments can reduce stress, anxiety, and depression. It has a calming effect on our nervous system, helping to lower our heart rate and blood pressure. The Japanese practice of "forest bathing" or shinrin-yoku encourages people to immerse themselves in the forest to reap these health benefits.
Moreover, nature reminds us of the importance of simplicity and balance. It operates in harmonious cycles, from the changing seasons to the intricate web of life in a forest ecosystem. Observing these natural rhythms can inspire us to seek balance in our own lives, to appreciate the different phases we go through, and to understand that each has its unique beauty.
Human connection is another essential aspect of our lives that often gets overshadowed by the demands of modernity. In the age of social media and virtual interactions, we may have thousands of "friends" online but still feel lonely and isolated. True connection goes beyond the digital realm; it involves genuine face-to-face interactions, deep conversations, and the warmth of physical touch.
Think about the last time you shared a hearty laugh with a close friend or embraced a loved one after a long separation. These moments of connection are precious and irreplaceable. They remind us of our shared humanity and the profound impact we have on each other's lives.
Building and maintaining meaningful relationships takes time and effort, but the rewards are immeasurable. When we open ourselves up to authentic connections, we create a support system that can help us navigate life's challenges. We gain a sense of belonging and purpose that enhances our overall well-being.
In today's world, where technology often drives a wedge between people, it's essential to prioritize genuine human connections. This means putting down our devices, making time for face-to-face interactions, and actively listening to one another. It means being vulnerable, sharing our joys and sorrows, and offering a shoulder to lean on when needed.
It's also worth noting that our connection with nature and our connection with each other are interconnected. When we spend time in nature with loved ones, we strengthen our bonds and create lasting memories. Whether it's a family hike in the mountains or a picnic in a park, these shared experiences deepen our connection to both the natural world and the people we care about.
Furthermore, nature provides a unique backdrop for introspection and meaningful conversations. Sitting around a campfire under a starlit sky, we find ourselves discussing life's big questions, sharing stories, and gaining new perspectives. Nature's beauty and serenity create a space for profound moments of connection and reflection.
The beauty of nature and human connection are, hence, two essential aspects of our lives that can enrich our physical and emotional well-being. Nature offers us solace and reminds us of the simplicity and balance that we often overlook in our busy lives. Human connection, on the other hand, nourishes our souls and gives us a sense of belonging and purpose. Embracing both nature and human relationships can lead to a more fulfilling and harmonious existence in our increasingly complex and interconnected world.
The Power of Curiosity: Fueling Innovation and Discovery
Curiosity is a driving force behind human progress, powering innovation, discovery, and personal growth. It's the insatiable desire to explore, learn, and understand the world around us. From the early days of human civilization to the cutting-edge research of today, curiosity has been the spark that ignites the flames of creativity and drives us to push the boundaries of what is known.
At its core, curiosity is about asking questions. It's about seeking answers, challenging assumptions, and delving deeper into the mysteries of life. Children are often the best examples of this innate curiosity, constantly asking "Why?" as they explore their surroundings. This natural inclination to inquire and explore is something that we should nurture throughout our lives.
One of the most remarkable aspects of curiosity is its ability to drive innovation. Many of humanity's greatest inventions and breakthroughs can be traced back to someone asking, "What if?" Consider the invention of the light bulb by Thomas Edison. Edison's relentless curiosity and countless experiments led to the development of a practical electric light, transforming the way we live and work.
In the realm of science, curiosity has fueled groundbreaking discoveries. Think of Marie Curie's pioneering work on radioactivity or Albert Einstein's relentless pursuit of understanding the universe's fundamental principles. These scientists were not satisfied with the status quo; they were driven by an insatiable curiosity to uncover the secrets of the natural world.
Moreover, curiosity is a powerful tool for personal growth and development. When we embrace curiosity, we open ourselves up to new experiences and perspectives. It encourages us to step out of our comfort zones, confront challenges, and learn from our failures. In this way, curiosity is not only a catalyst for external innovation but also for internal transformation.
In the age of the internet, access to information has never been easier. Curiosity-driven learning has become a cornerstone of education and self-improvement. Online courses, tutorials, and a vast array of educational resources are readily available to anyone with a thirst for knowledge. Curious individuals can explore topics ranging from ancient history to cutting-edge technology with just a few clicks.
Furthermore, curiosity fosters empathy and understanding. When we approach others with a genuine desire to learn about their experiences, beliefs, and perspectives, we build bridges of connection and promote tolerance. Curiosity allows us to see beyond stereotypes and biases, leading to more inclusive and compassionate communities.
In the business world, curiosity is a driving force behind successful entrepreneurship. Entrepreneurs often start with a simple question: "Is there a better way to do this?" This question can lead to innovative solutions, new products, and thriving businesses. Companies that encourage a culture of curiosity among their employees tend to be more adaptable and competitive in a rapidly changing marketplace.
While curiosity is a powerful force for good, it can also be challenging to maintain in a world filled with distractions and instant gratification. In our quest for quick answers and immediate rewards, we may overlook the value of deep inquiry and prolonged exploration. It's essential to carve out time for reflection and to nurture our innate curiosity continually.
Curiosity is, therefore, a fundamental aspect of the human experience that drives progress, innovation, and personal growth. It empowers us to ask questions, seek answers, and explore the unknown. Whether it's sparking a scientific revolution, fostering personal development, or building bridges of understanding, curiosity has the potential to shape a brighter future for individuals and society as a whole. So, let us embrace our curiosity, feed our hunger for knowledge, and continue to explore the boundless possibilities of our world.
"""

# %%
#Creating a Doc object
doc=nlp(text)

# %%
# Initializing lists to store relevant tokens
relevant_tokens = []

# %%
# We define a function to filter out irrelevant tokens. We check if the token consists of only alphabets(letters) and not numerals or symbols using is_alpha.
# Then we check whether it is not a stop word
stop_words=set(spacy.lang.en.stop_words.STOP_WORDS)

def is_token_relevant(token):
    if token.is_alpha and token.text.lower() not in stop_words:
      return token

# %%
# Iterating through tokens in the document and filtering relevant tokens (by appending into the relevant_tokens list):
for token in doc:
    if is_token_relevant(token):
        relevant_tokens.append([token.text,token.pos_, token.dep_, token.lemma_])

# %%
# Printing the relevant tokens along with their POS (Part of Speech), DEP, and lemma
from tabulate import tabulate

headers = ["Text", "POS", "DEP", "LEMMA"]
table = tabulate(relevant_tokens, headers, tablefmt="grid")
print(table)
# Out:
# +------------------+-------+-----------+------------------+
# | Text             | POS   | DEP       | LEMMA            |
# +==================+=======+===========+==================+
# | year             | NOUN  | pobj      | year             |
# +------------------+-------+-----------+------------------+
# | world            | NOUN  | nsubj     | world            |
# +------------------+-------+-----------+------------------+
# | faced            | VERB  | ROOT      | face             |
# +------------------+-------+-----------+------------------+
# | challenges       | NOUN  | dobj      | challenge        |
# +------------------+-------+-----------+------------------+
# | including        | VERB  | prep      | include          |
# +------------------+-------+-----------+------------------+
# | pandemic         | ADJ   | amod      | pandemic         |
# +------------------+-------+-----------+------------------+
# | began            | VERB  | relcl     | begin            |
# ...

# %%
entities=[]

for ent in doc.ents:
  entities.append([ent.text, ent.label_, spacy.explain(ent.label_)])

ent_headers=["Entity", "Entity Label", "Label Description"]
table2 = tabulate(entities, ent_headers, tablefmt="grid")
print(table2)
# Out:
# +--------------------------------------------+----------------+------------------------------------------------------+
# | Entity                                     | Entity Label   | Label Description                                    |
# +============================================+================+======================================================+
# | the year 2023                              | DATE           | Absolute or relative dates or periods                |
# +--------------------------------------------+----------------+------------------------------------------------------+
# | COVID-19                                   | ORG            | Companies, agencies, institutions, etc.              |
# +--------------------------------------------+----------------+------------------------------------------------------+
# | 2019                                       | DATE           | Absolute or relative dates or periods                |
# ...
